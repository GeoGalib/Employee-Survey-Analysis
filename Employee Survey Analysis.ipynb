# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv('employee_survey.csv')

# %%
data.head(10)
# Out:
#    EmpID  Gender  Age MaritalStatus        JobLevel  Experience        Dept  \
# 0      6    Male   32       Married             Mid           7          IT
# 1     11  Female   34       Married             Mid          12     Finance
# 2     33  Female   23        Single  Intern/Fresher           1   Marketing
# 3     20  Female   29       Married          Junior           6          IT
# 4     28   Other   23        Single          Junior           1       Sales
# 5     45  Female   33       Married             Mid          10  Operations
# 6     21  Female   26        Single          Junior           4       Sales
# 7     44    Male   24        Single          Junior           2          IT
# 8      7  Female   29       Married          Junior           7   Marketing
# 9     15  Female   24        Single             Mid           2   Marketing
#
#      EmpType  WLB  WorkEnv  ...  SleepHours       CommuteMode  \
# 0  Full-Time    1        1  ...         7.6               Car
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3025 entries, 0 to 3024
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   EmpID                  3025 non-null   int64
#  1   Gender                 3025 non-null   object
#  2   Age                    3025 non-null   int64
#  3   MaritalStatus          3025 non-null   object
#  4   JobLevel               3025 non-null   object
#  5   Experience             3025 non-null   int64
#  6   Dept                   3025 non-null   object
#  7   EmpType                3025 non-null   object
#  8   WLB                    3025 non-null   int64
#  9   WorkEnv                3025 non-null   int64
#  10  PhysicalActivityHours  3025 non-null   float64
#  11  Workload               3025 non-null   int64
#  12  Stress                 3025 non-null   int64
#  13  SleepHours             3025 non-null   float64
# ...

# %%
data.isna().sum()
# Out:
# EmpID                    0
# Gender                   0
# Age                      0
# MaritalStatus            0
# JobLevel                 0
# Experience               0
# Dept                     0
# EmpType                  0
# WLB                      0
# WorkEnv                  0
# PhysicalActivityHours    0
# Workload                 0
# Stress                   0
# SleepHours               0
# CommuteMode              0
# CommuteDistance          0
# NumCompanies             0
# TeamSize                 0
# NumReports               0
# EduLevel                 0
# haveOT                   0
# TrainingHoursPerYear     0
# JobSatisfaction          0
# dtype: int64

# %% [markdown]
# **EmpID**	Unique identifier for each employee.
#
# **Gender**	Gender of the employee (e.g., Male, Female, Other).
#
# **Age**	Age of the employee.
#
# **MaritalStatus**	Marital status of the employee (e.g., Single, Married, Divorced, Widowed).
#
# **JobLevel**	Job level of the employee (e.g., Intern/Fresher, Junior, Mid, Senior, Lead).
#
# **Experience**	Number of years of work experience the employee has.
#
# **Dept**	Department where the employee works (e.g., IT, HR, Finance, Marketing, Sales, Legal, Operations, Customer Service).
#
# **EmpType**	Type of employment (e.g., Full-Time, Part-Time, Contract).
#
# **WLB**	Work-life balance rating (scale from 1 to 5).
#
# **WorkEnv**	Work environment rating (scale from 1 to 5).
#
# **PhysicalActivityHours**	Number of hours of physical activity per week.
#
# **Workload**	Workload rating (scale from 1 to 5).
#
# **Stress**	Stress level rating (scale from 1 to 5).
#
# **SleepHours**	Number of hours of sleep per night.
#
# **CommuteMode**	Mode of commute (e.g., Car, Public Transport, Bike, Walk, Motorbike).
#
# **CommuteDistance**	Distance traveled during the commute (in kilometers).
#
# **NumCompanies**	Number of different companies the employee has worked for.
#
# **TeamSize**	Size of the team the employee is part of.
#
# **NumReports**	Number of people reported to by the employee (only applicable for Senior and Lead levels).
#
# **EduLevel**	Highest level of education achieved by the employee (e.g., High School, Bachelor, Master, PhD).
#
# **haveOT**	Indicator if the employee has overtime (True/False).
#
# **TrainingHoursPerYear**	Number of hours of training received per year.
#
# **JobSatisfaction**	Rating of job satisfaction (scale from 1 to 5).

# %%
gender_count = data['Gender'].value_counts()

# %%
gender_count
# Out:
# Gender
# Male      1528
# Female    1240
# Other      257
# Name: count, dtype: int64

# %%
data.describe()
# Out:
#              EmpID          Age   Experience          WLB      WorkEnv  \
# count  3025.000000  3025.000000  3025.000000  3025.000000  3025.000000
# mean   1513.000000    35.741818     9.082645     3.061157     3.029091
# std     873.386608    10.191833     7.073344     1.447001     1.415317
# min       1.000000    22.000000     0.000000     1.000000     1.000000
# 25%     757.000000    27.000000     3.000000     2.000000     2.000000
# 50%    1513.000000    34.000000     8.000000     3.000000     3.000000
# 75%    2269.000000    43.000000    14.000000     4.000000     4.000000
# max    3025.000000    60.000000    29.000000     5.000000     5.000000
#
#        PhysicalActivityHours     Workload       Stress   SleepHours  \
# count            3025.000000  3025.000000  3025.000000  3025.000000
# mean                2.029620     2.966612     1.736529     7.005983
# std                 0.966014     1.401486     1.064242     1.002652
# ...

# %%
marital_status_1 = data['MaritalStatus'].unique()
print(marital_status_1)
# Out:
# ['Married' 'Single' 'Divorced' 'Widowed']

# %%
marital_status_value_count = data['MaritalStatus'].value_counts()
marital_status_value_count
# Out:
# MaritalStatus
# Single      1437
# Married     1397
# Divorced     189
# Widowed        2
# Name: count, dtype: int64

# %%
marital_status_value_count.plot(kind='bar')
plt.title('Number of people based on Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Number Count')
plt.show()

# %%
Widowed_people = data[data['MaritalStatus'] == 'Widowed']
Widowed_people
# Out:
#       EmpID Gender  Age MaritalStatus JobLevel  Experience     Dept  \
# 2022   1514   Male   53       Widowed     Lead          27       IT
# 2928   2049   Male   54       Widowed     Lead          11  Finance
#
#         EmpType  WLB  WorkEnv  ...  SleepHours       CommuteMode  \
# 2022   Contract    1        4  ...         7.9  Public Transport
# 2928  Full-Time    4        2  ...         6.7               Car
#
#       CommuteDistance  NumCompanies TeamSize  NumReports  EduLevel  haveOT  \
# 2022               11            10       26           1  Bachelor   False
# 2928               28            10       28           4       PhD   False
#
#       TrainingHoursPerYear JobSatisfaction
# 2022                  63.5               4
# 2928                  55.5               4
#
# [2 rows x 23 columns]

# %%
different_job_level = data['JobLevel'].unique()
print(different_job_level)
# Out:
# ['Mid' 'Intern/Fresher' 'Junior' 'Senior' 'Lead']

# %%
different_commute_mode = data['CommuteMode'].unique()
print(different_commute_mode)
# Out:
# ['Car' 'Motorbike' 'Public Transport' 'Bike' 'Walk']

# %%
different_departments = data['Dept'].unique()
print(different_departments)
# Out:
# ['IT' 'Finance' 'Marketing' 'Sales' 'Operations' 'Customer Service'
#  'Legal' 'HR']

# %%
job_level_count = data['JobLevel'].value_counts()
job_level_count
# Out:
# JobLevel
# Senior            1069
# Mid                766
# Junior             602
# Lead               386
# Intern/Fresher     202
# Name: count, dtype: int64

# %%
job_level_count.plot(kind = 'bar')
plt.title('Number of Employees by Designation')
plt.xlabel('Employee Designations')
plt.ylabel('Number of Employees')
plt.show()

# %% [markdown]
# **Now I want to see which department people sleeps the most**

# %%
Departments_Vs_Sleeptime = data.groupby('Dept')['SleepHours'].mean().sort_values()
Departments_Vs_Sleeptime.plot(kind='bar')
plt.title('Departments vs Sleeptime')
plt.xlabel('Name of Departments')
plt.ylabel('Average Sleep Time')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Dept', y='JobSatisfaction', data=data, order=data.groupby('Dept')['JobSatisfaction'].mean().sort_values().index)
plt.title('Average Job Satisfaction by Department')
plt.xlabel('Department')
plt.ylabel('Average Job Satisfaction Score')
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.barplot(x='Gender', y='JobSatisfaction', data=data)
plt.title('Average Job Satisfaction by Gender')
plt.xlabel('Gender')
plt.ylabel('Average Job Satisfaction Score')
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.barplot(x='haveOT', y='JobSatisfaction', data=data)
plt.title('Average Job Satisfaction by Overtime Factor')
plt.xlabel('OT True Vs False')
plt.ylabel('Average Job Satisfaction Score')
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.barplot(x='MaritalStatus', y='JobSatisfaction', data=data)
plt.title('Average Job Satisfaction by Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Average Job Satisfaction Score')
plt.show()

# %%
# Create age bins
age_bins = np.arange(20, 70, 10)  # adjust the bin size as needed

# Assign each age to a bin
data['AgeBin'] = pd.cut(data['Age'], bins=age_bins, labels=[f'{b}-{b+9}' for b in age_bins[:-1]])

# Plot the data
plt.figure(figsize=(6, 6))
sns.barplot(x='AgeBin', y='JobSatisfaction', data=data, order=data.groupby('AgeBin', observed=False)['JobSatisfaction'].mean().sort_values().index)
plt.title('Average Job Satisfaction by Age Bin')
plt.xlabel('Age Bin')
plt.ylabel('Average Job Satisfaction Score')
plt.show()

# %%
# Create age bins
training_hours_bins = np.arange(10, 80, 10)  # adjust the bin size as needed

# Assign each age to a bin
data['TrainingBin'] = pd.cut(data['TrainingHoursPerYear'], bins=training_hours_bins, labels=[f'{b}-{b+9}' for b in training_hours_bins[:-1]])

# Plot the data
plt.figure(figsize=(6, 6))
sns.barplot(x='TrainingBin', y='JobSatisfaction', data=data)
plt.title('Average Job Satisfaction by Training Hours')
plt.xlabel('Training hours per year')
plt.ylabel('Average Job Satisfaction Score')
plt.show()

# %%
avg_stats_by_marital_status = data.select_dtypes(include=['int64', 'float64']).groupby(data['MaritalStatus']).mean()
avg_stats_by_marital_status
# Out:
#                      EmpID        Age  Experience       WLB   WorkEnv  \
# MaritalStatus
# Divorced       1585.402116  45.349206   12.798942  3.015873  3.111111
# Married        1493.138869  40.571940   11.846099  3.037938  3.048676
# Single         1522.411969  29.757829    5.893528  3.090466  2.999304
# Widowed        1781.500000  53.500000   19.000000  2.500000  3.000000
#
#                PhysicalActivityHours  Workload    Stress  SleepHours  \
# MaritalStatus
# Divorced                    2.196825  3.010582  1.629630    7.112698
# Married                     2.022978  2.955619  1.751611    6.962491
# Single                      2.013918  2.970772  1.736952    7.033820
# Widowed                     2.150000  3.500000  1.000000    7.300000
#
#                CommuteDistance  NumCompanies   TeamSize  NumReports  \
# MaritalStatus
# Divorced             12.947090      7.433862  20.179894    3.947090
# Married              13.521117      5.848246  18.113815    3.311382
# ...

# %%
marital_status_value_count = data['MaritalStatus'].value_counts()
marital_status_value_count
# Out:
# MaritalStatus
# Single      1437
# Married     1397
# Divorced     189
# Widowed        2
# Name: count, dtype: int64

# %%
data.head()
# Out:
#    EmpID  Gender  Age MaritalStatus        JobLevel  Experience       Dept  \
# 0      6    Male   32       Married             Mid           7         IT
# 1     11  Female   34       Married             Mid          12    Finance
# 2     33  Female   23        Single  Intern/Fresher           1  Marketing
# 3     20  Female   29       Married          Junior           6         IT
# 4     28   Other   23        Single          Junior           1      Sales
#
#      EmpType  WLB  WorkEnv  ...  CommuteDistance  NumCompanies  TeamSize  \
# 0  Full-Time    1        1  ...               20             3        12
# 1  Full-Time    1        1  ...               15             4        11
# 2  Full-Time    2        4  ...               17             0        30
# 3   Contract    2        2  ...               13             2         9
# 4  Part-Time    3        1  ...               20             0         7
#
#    NumReports  EduLevel  haveOT  TrainingHoursPerYear  JobSatisfaction  \
# ...

# %%
avg_stats_by_job_roles = data.select_dtypes(include=['int64', 'float64']).groupby(data['JobLevel']).mean()
avg_stats_by_job_roles
# Out:
#                       EmpID        Age  Experience       WLB   WorkEnv  \
# JobLevel
# Intern/Fresher  1478.678218  22.485149    0.485149  2.990099  3.094059
# Junior          1473.004983  25.490033    3.267442  3.051495  2.990033
# Lead            1463.528497  50.321244   15.409326  2.906736  3.163212
# Mid             1530.082245  35.420366    9.967363  3.161880  2.959530
# Senior          1547.631431  38.985968   11.063611  3.063611  3.040225
#
#                 PhysicalActivityHours  Workload    Stress  SleepHours  \
# JobLevel
# Intern/Fresher               2.047030  2.965347  1.782178    6.999010
# Junior                       1.962458  3.046512  1.692691    7.048007
# Lead                         2.073575  3.049223  1.784974    7.044041
# Mid                          2.051828  2.889034  1.729765    6.982507
# Senior                       2.032367  2.947615  1.739944    6.986717
#
#                 CommuteDistance  NumCompanies   TeamSize  NumReports  \
# JobLevel
# ...

# %%
avg_stats_by_dept = data.select_dtypes(include=['int64', 'float64']).groupby(data['Dept']).mean()
Stats_by_dept = avg_stats_by_dept.drop(columns=['EmpID'])
Stats_by_dept
# Out:
#                         Age  Experience       WLB   WorkEnv  \
# Dept
# Customer Service  35.802721    9.360544  2.761905  2.938776
# Finance           35.613815    9.048666  3.097331  3.009419
# HR                36.209790    9.657343  2.769231  3.041958
# IT                35.700258    9.021964  3.050388  3.118863
# Legal             34.908088    8.908088  3.102941  3.011029
# Marketing         36.382911    9.386076  3.142405  2.765823
# Operations        36.193407    8.942857  3.061538  3.109890
# Sales             35.231317    8.943060  3.181495  3.049822
#
#                   PhysicalActivityHours  Workload    Stress  SleepHours  \
# Dept
# Customer Service               2.040816  2.857143  1.693878    7.046259
# Finance                        2.090581  2.998430  1.813187    6.999372
# HR                             2.096503  2.790210  1.762238    6.880420
# IT                             2.016925  2.981912  1.682171    7.087209
# ...

# %% [markdown]
# **Final Observation**
#
# So it seems like the Job Satisfaction level is only affected by some key factors. The most notable factor here is the marital status where Married people are the least satisfied with their job which is a bit concerning as the the majority of the company are filled with married people.
#
# People doing overtime are also not satisfied with their job which is to be expected as it is a common scenario.
#
# Male people are relatively not satisfied with their job compared to female or other gender.
#
# The two widowed people in the company who are senior citizen are very happy with their current position.
#
# People age between 40-50 are the most happiest in their current position.
#
# As of department special care needs to be given to IT, Customer Service and Marketing Department as they are not much happy with their job.
#
# It seems like upto 60 hours of training per year is enough as anything more than that affect the job satisfaction level.
#
# As of now the current data has only provided which category of people are least satisfied with their job, however it does not provide the reason.
